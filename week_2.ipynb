# %% [markdown]
# <a href="https://colab.research.google.com/github/lelyta30/PCVK_GENAP_2023/blob/main/week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name  : Lelyta Salsabila
#
# Class : 3I
#
# NIM   : 1941720026
#
# Absen : 05

# %% [markdown]
# Image with BGR channel preview

# %%
from google.colab import drive
#Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE) #BGR channel conversion => BGR
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='magma')

# %%
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#save the image file
#cv.imwriteimread('/content/drive/MyDrive/PCVK/mandrill2.tiff',img5)

#show the plot with a larger canvas size

fig = plt.figure(figsize=(10,10)) #resize(10,10) as needed
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# #Creating 2D image

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img2)

# %%
cv.rectangle(black_img2,pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10) #(x,y)
#pt1 = coordinate of UPPER LEFT corner
#pt2 = coordinate of BUTTOM LEFT corner
plt.imshow(black_img2)

# %%
cv.rectangle(black_img2, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness = 15)
plt.imshow(black_img2)

# %%
cv.circle(black_img2, center=(100,100), radius=50, color=(255,0,0), thickness = 8)
plt.imshow(black_img2)

# %%
cv.line(black_img2,pt1=(0,0),pt2=(512,512),color=(255,255,255), thickness=5)
plt.imshow(black_img2)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img2, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2,lineType=cv.LINE_AA )
plt.imshow(black_img2)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int3

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R,G,B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# #QUESTIONS & ANSWER
#
# 1. What is the difference between the images displayed without and with matplotlib?
# 2. What is the difference and effect of creating a black image between int16 and int32
# data types?
# 3. What is the use of "google.colab.patches import cv2_imshow" in the following code snippet
# 4. What is the use of "skimage import io" in the code snippet for question number 3

# %% [markdown]
#                                       ANSWER
# 1. Images displayed with matplotlib can represent data into colors and glyphs such as markers (circles), lines (lines) and polygons. Meanwhile, images displayed without matplotlib cannot represent data like images displayed using matplotlib.
# 2. the difference in the size of the image, depending on the int. the smaller the given int data type, the less capacity it will have and the larger the given int data type, the greater the capacity. Only the capacity is different from int16 and int32
# 3. The above line adds one patch because cv.imshow doesn't run on Google Colab nor Jupyter Notebook. The img variable is the original image, while the grayImg is restricted to black and white (gray).
# 4. to load images, read and write images

# %% [markdown]
# 1. By using figsize, notice whether the image pixel size also changes?

# %%
img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
tinggi = img6.shape[0]
lebar = img6.shape[1]
print("reslusi image: tinggixlebar = ", tinggi,' x ', lebar)


plt.imshow(img6)
# Out:
# reslusi image: tinggixlebar =  627  x  670

# %%
img7 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10)) #we can change the size value other than (10,10)
ax = fig.add_subplot(111)#
tinggi = img6.shape[0]
lebar = img6.shape[1]
print("reslusi image: tinggixlebar = ", tinggi,' x ', lebar)



ax.imshow(img6)
# Out:
# reslusi image: tinggixlebar =  627  x  670

# %% [markdown]
# 2. Show images in Red-Blue and Green-Blue channels only!

# %%
#use NumPy indexing
#index 0 = red; 1=green, 2= blue

# Extract green and blue channels
green_blue_image = np.zeros_like(img6)
green_blue_image[:, :, 1] = img6[:, :, 1]  # Green channel
green_blue_image[:, :, 2] = img6[:, :, 2]  # Blue channel

# Display green-blue image using plt.imshow
plt.imshow(green_blue_image)
plt.show()

# %%
#use NumPy indexing
#index 0 = red; 1=green, 2= blue

# Extract green and blue channels
green_blue_image = np.zeros_like(img6)
green_blue_image[:, :, 0] = img6[:, :, 0]  # Red channel
green_blue_image[:, :, 2] = img6[:, :, 2]  # Blue channel

# Display green-blue image using plt.imshow
plt.imshow(green_blue_image)
plt.show()

# %%
#using img6
#using function
# Convert image to grayscale
gray_image = cv.cvtColor(img6, cv.COLOR_BGR2GRAY)

# Create red-blue color map
cmap = plt.cm.get_cmap('RdBu')

# Convert grayscale image to red-blue image using color map
rb_image = cmap(gray_image)

# Show red-blue image
plt.imshow(rb_image)
plt.axis('off')
plt.show()

# %% [markdown]
# Show image row 20-115, column 25-120!

# %%
# Extract rows 20 to 115
img7 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
image_rows = img7[20:116, :, :]

# Display extracted rows using plt.imshow
plt.imshow(image_rows)
plt.show()

# %%
# Extract rows 25 to 119
image_rows = img6[:, 25:119, :]

# Display extracted rows using plt.imshow
plt.imshow(image_rows)
plt.show()

# %% [markdown]
# Show image rows 5-30, all columns, channel Red only!

# %%
# Extract rows 5 to 30
image_rows = img6[5:30, :,0]

# Display extracted rows using plt.imshow
plt.imshow(image_rows)
plt.show()

# %% [markdown]
# 5. Create 5 boxes of different sizes and colors in one image. it is recommended to use random numbers

# %%
kitten01 = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(kitten01)
tinggi = kitten01.shape[0]
lebar = kitten01.shape[1]
print("reslusi image: tinggixlebar = ", tinggi,' x ', lebar)
# Out:
# reslusi image: tinggixlebar =  627  x  670

# %%
kitten013 = cv.cvtColor(kitten01,cv.COLOR_BGR2RGB)
plt.imshow(kitten013)

# %%
lily = cv.imread('/content/drive/MyDrive/PCVK/lily.jpg')
lily1 = lily
lily1 = cv.cvtColor(lily,cv.COLOR_BGR2RGB)
plt.imshow(lily1)
tinggi = lily1.shape[0]
lebar = lily1.shape[1]
print("reslusi image: tinggixlebar = ", tinggi,' x ', lebar)
# Out:
# reslusi image: tinggixlebar =  599  x  623

# %%
import random

lily2 = lily1

for i in range(5):#generate 5 random boxes
  x = np.random.randint(0, 512 - 50)  # Random x coordinate, the pixel
  y = np.random.randint(0, 512 - 50)  # Random y coordinate
  w = np.random.randint(10, 35)       # Random width, the size of the box
  h = np.random.randint(10, 35)       # Random height
  r = np.random.randint(0, 256)       # Random red value
  g = np.random.randint(0, 256)       # Random green value
  b = np.random.randint(0, 256)       # Random blue value
  color = (r, g, b)                   # Random color
    
    # Draw the box on the image
  lily2[y:y+h, x:x+w, :] = color

# Display the image
plt.imshow(lily2)
plt.show()

# %%
import random

lily7 = lily2

for i in range(5):#generate 5 random boxes
  x = np.random.randint(0, 100 - 50)  # Random x coordinate, the pixel
  y = np.random.randint(0, 100 - 50)  # Random y coordinate
  w = np.random.randint(10, 15)       # Random width, the size of the box
  h = np.random.randint(10, 15)       # Random height
  r = np.random.randint(0, 256)       # Random red value
  g = np.random.randint(0, 256)       # Random green value
  b = np.random.randint(0, 256)       # Random blue value
  color = (r, g, b)                   # Random color
    
    # Draw the box on the image
  lily7[y:y+h, x:x+w, :] = color

# Display the image
plt.imshow(lily7)
plt.show()

# %% [markdown]
# 6. Show the image upside down!

# %%
lily3 = cv.flip(lily2, 0)
plt.imshow(lily3)

# %%
# lily5 = cv.flip(cv.cvtColor(lily,cv.COLOR_BGR2RGB), 0)
lily5 = cv.flip(lily7, 0)
plt.imshow(lily5)

# %% [markdown]
# 7. Based on practicum sections 3 and 4, Make rectangles and circles on the face of your photo image when you are active

# %%
# Extract rows 20 to 115
kitten01 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
kitten011 = kitten01[20:116, :, :]

# Display extracted rows using plt.imshow
#pt1 = kanan bawah
# pt2 = kiri atas
cv.rectangle(kitten011, pt1=(200,50), pt2=(100,25), color=(0,0,255), thickness = 8)
cv.circle(kitten011, center=(175,75), radius=25, color=(255,0,0), thickness = 8)

plt.imshow(kitten011)

plt.show()

# %% [markdown]
# 8. Create a rectangle in the lower left corner of channel B in the RGB color space from

# %%
kitten01 = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
kitten011 = kitten01
kitten011 = cv.cvtColor(kitten01,cv.COLOR_BGR2RGB)
plt.imshow(kitten011)
tinggi = kitten011.shape[0]
lebar = kitten011.shape[1]
print("reslusi image: tinggixlebar = ", tinggi,' x ', lebar)
# Out:
# reslusi image: tinggixlebar =  627  x  670

# %%
#use NumPy indexing
#index 0 = red; 1=green, 2= blue

# Extract green and blue channels
kitten012 =cv.cvtColor(kitten01,cv.COLOR_BGR2RGB) 
kitten013 = np.zeros_like(kitten012)
kitten013[:, :, 1] = kitten012[:, :, 1]  # Green channel

#display rectangle
#pt1 = kanan bawah
# pt2 = kiri atas
cv.rectangle(kitten013, pt1=(500,1700), pt2=(50,1600), color=(255,0,0), thickness = 15)

# Display green-blue image using plt.imshow
plt.imshow(kitten013)
plt.show()

# %% [markdown]
# 9.Complete the writing of the file name on the image file from question no.8. use the font, font size, and font color according to your wishes.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
kitten014 = kitten013 #make a copy 
cv.putText(kitten014, text='Buzzed Like a Bee', org=(50,400), fontFace=font, fontScale=4, color=(255,0,255), thickness=2,lineType=cv.LINE_AA )
plt.imshow(kitten014)
